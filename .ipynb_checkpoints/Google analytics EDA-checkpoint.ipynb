# %% [markdown]
# ## Google analytics customer revenue predictions
# ### By Ahmed Eweed
#
# ### You can find me on github at [github.com/AhmedEweed](https://github.com/AhmedEweed)

# %% [markdown]
#     I re approached the dataset as I explored it in many ways
#     and this version is the updated version of my exploration

# %%
import os
import json
import numpy as np
import pandas as pd
from pandas.io.json import json_normalize
# load dataset with flattening only the totals column
def load_df(csv_path='../train.csv', nrows=None):
    JSON_COLUMNS = ['totals']
    df = pd.read_csv(csv_path, 
                     converters={column: json.loads for column in JSON_COLUMNS}, 
                     dtype={'fullVisitorId': 'str'}, # Important!!
                     nrows=nrows)
    
    for column in JSON_COLUMNS:
        column_as_df = json_normalize(df[column])
        column_as_df.columns = [f"{column}.{subcolumn}" for subcolumn in column_as_df.columns]
        df = df.drop(column, axis=1).merge(column_as_df, right_index=True, left_index=True)
    print(f"Loaded {os.path.basename(csv_path)}. Shape: {df.shape}")
    return df

# %%
#load dataset
df = load_df()
df.head()
# Out:
# Loaded train.csv. Shape: (903653, 17)
#   channelGrouping      date  \
# 0  Organic Search  20160902
# 1  Organic Search  20160902
# 2  Organic Search  20160902
# 3  Organic Search  20160902
# 4  Organic Search  20160902
#
#                                               device fullVisitorId  \
# 0  {"browser": "Chrome", "browserVersion": "not a...   1.13166E+18
# 1  {"browser": "Firefox", "browserVersion": "not ...   3.77306E+17
# 2  {"browser": "Chrome", "browserVersion": "not a...   3.89555E+18
# 3  {"browser": "UC Browser", "browserVersion": "n...   4.76345E+18
# 4  {"browser": "Chrome", "browserVersion": "not a...   2.72944E+16
#
#                                           geoNetwork  \
# 0  {"continent": "Asia", "subContinent": "Western...
# 1  {"continent": "Oceania", "subContinent": "Aust...
# 2  {"continent": "Europe", "subContinent": "South...
# 3  {"continent": "Asia", "subContinent": "Southea...
# 4  {"continent": "Europe", "subContinent": "North...
#
#                         sessionId  socialEngagementType  \
# 0  1131660440785968503_1472830385  Not Socially Engaged
# 1   377306020877927890_1472880147  Not Socially Engaged
# 2  3895546263509774583_1472865386  Not Socially Engaged
# 3  4763447161404445595_1472881213  Not Socially Engaged
# 4    27294437909732085_1472822600  Not Socially Engaged
#
#                                        trafficSource     visitId  visitNumber  \
# 0  {"campaign": "(not set)", "source": "google", ...  1472830385            1
# 1  {"campaign": "(not set)", "source": "google", ...  1472880147            1
# 2  {"campaign": "(not set)", "source": "google", ...  1472865386            1
# 3  {"campaign": "(not set)", "source": "google", ...  1472881213            1
# 4  {"campaign": "(not set)", "source": "google", ...  1472822600            2
#
#    visitStartTime totals.bounces totals.hits totals.newVisits  \
# 0      1472830385              1           1                1
# 1      1472880147              1           1                1
# 2      1472865386              1           1                1
# 3      1472881213              1           1                1
# 4      1472822600              1           1              NaN
#
#   totals.pageviews totals.transactionRevenue totals.visits
# 0                1                       NaN             1
# 1                1                       NaN             1
# 2                1                       NaN             1
# 3                1                       NaN             1
# 4                1                       NaN             1

# %%
# look up the datatypes present in the dataset
df.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 903653 entries, 0 to 903652
# Data columns (total 17 columns):
# channelGrouping              903653 non-null object
# date                         903653 non-null int64
# device                       903653 non-null object
# fullVisitorId                903653 non-null object
# geoNetwork                   903653 non-null object
# sessionId                    903653 non-null object
# socialEngagementType         903653 non-null object
# trafficSource                903653 non-null object
# visitId                      903653 non-null int64
# visitNumber                  903653 non-null int64
# visitStartTime               903653 non-null int64
# totals.bounces               450630 non-null object
# totals.hits                  903653 non-null object
# totals.newVisits             703060 non-null object
# totals.pageviews             903553 non-null object
# totals.transactionRevenue    11515 non-null object
# totals.visits                903653 non-null object
# dtypes: int64(4), object(13)
# memory usage: 72.4+ MB

# %%
# convert revenue to float
df['totals.transactionRevenue'] = df['totals.transactionRevenue'].astype(float)

# %%
# extract only numeric values of revenue
df_part = df[df['totals.transactionRevenue'] > 0.0]

# %%
# reset the index of the the new extracted dataset
df_part = df_part.reset_index(drop = True)

# %%
# look at the new dataset
df_part.head()
# Out:
#   channelGrouping      date  \
# 0          Direct  20160902
# 1  Organic Search  20160902
# 2        Referral  20160902
# 3        Referral  20160902
# 4        Referral  20160902
#
#                                               device fullVisitorId  \
# 0  {"browser": "Chrome", "browserVersion": "not a...   6.19419E+18
# 1  {"browser": "Chrome", "browserVersion": "not a...   5.32717E+18
# 2  {"browser": "Chrome", "browserVersion": "not a...   8.88505E+18
# 3  {"browser": "Chrome", "browserVersion": "not a...   1.85468E+17
# 4  {"browser": "Chrome", "browserVersion": "not a...   3.24489E+18
#
#                                           geoNetwork  \
# 0  {"continent": "Americas", "subContinent": "Nor...
# 1  {"continent": "Americas", "subContinent": "Nor...
# 2  {"continent": "Americas", "subContinent": "Nor...
# 3  {"continent": "Americas", "subContinent": "Nor...
# 4  {"continent": "Americas", "subContinent": "Nor...
#
#                         sessionId  socialEngagementType  \
# 0  6194193421514403509_1472843572  Not Socially Engaged
# 1  5327166854580374902_1472844906  Not Socially Engaged
# 2  8885051388942907862_1472827393  Not Socially Engaged
# 3  0185467632009737931_1472846398  Not Socially Engaged
# 4  3244885836845029978_1472824817  Not Socially Engaged
#
#                                        trafficSource     visitId  visitNumber  \
# 0  {"campaign": "(not set)", "source": "(direct)"...  1472843572            1
# 1  {"campaign": "(not set)", "source": "google", ...  1472844906            3
# 2  {"referralPath": "/", "campaign": "(not set)",...  1472827393            7
# 3  {"referralPath": "/", "campaign": "(not set)",...  1472846398            6
# 4  {"referralPath": "/", "campaign": "(not set)",...  1472824817            4
#
#    visitStartTime totals.bounces totals.hits totals.newVisits  \
# 0      1472843572            NaN          11                1
# 1      1472844906            NaN          11              NaN
# 2      1472827393            NaN          13              NaN
# 3      1472846398            NaN          13              NaN
# 4      1472824817            NaN          17              NaN
#
#   totals.pageviews  totals.transactionRevenue totals.visits
# 0               11                 37860000.0             1
# 1               10                306670000.0             1
# 2               11                 68030000.0             1
# 3               12                 26250000.0             1
# 4               14                574150000.0             1

# %%
# look at the dimensions and datatypes
df_part.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 11515 entries, 0 to 11514
# Data columns (total 17 columns):
# channelGrouping              11515 non-null object
# date                         11515 non-null int64
# device                       11515 non-null object
# fullVisitorId                11515 non-null object
# geoNetwork                   11515 non-null object
# sessionId                    11515 non-null object
# socialEngagementType         11515 non-null object
# trafficSource                11515 non-null object
# visitId                      11515 non-null int64
# visitNumber                  11515 non-null int64
# visitStartTime               11515 non-null int64
# totals.bounces               0 non-null object
# totals.hits                  11515 non-null object
# totals.newVisits             4465 non-null object
# totals.pageviews             11515 non-null object
# totals.transactionRevenue    11515 non-null float64
# totals.visits                11515 non-null object
# dtypes: float64(1), int64(4), object(12)
# memory usage: 989.6+ KB

# %%
# look up the date column format
df_part['date'].head()
# Out:
# 0    20160902
# 1    20160902
# 2    20160902
# 3    20160902
# 4    20160902
# Name: date, dtype: int64

# %%
# converting date to the right format
df_part['date'] = pd.to_datetime(df_part['date'], format = '%Y%m%d')
df_part.head()
# Out:
#   channelGrouping       date  \
# 0          Direct 2016-09-02
# 1  Organic Search 2016-09-02
# 2        Referral 2016-09-02
# 3        Referral 2016-09-02
# 4        Referral 2016-09-02
#
#                                               device fullVisitorId  \
# 0  {"browser": "Chrome", "browserVersion": "not a...   6.19419E+18
# 1  {"browser": "Chrome", "browserVersion": "not a...   5.32717E+18
# 2  {"browser": "Chrome", "browserVersion": "not a...   8.88505E+18
# 3  {"browser": "Chrome", "browserVersion": "not a...   1.85468E+17
# 4  {"browser": "Chrome", "browserVersion": "not a...   3.24489E+18
#
#                                           geoNetwork  \
# 0  {"continent": "Americas", "subContinent": "Nor...
# 1  {"continent": "Americas", "subContinent": "Nor...
# 2  {"continent": "Americas", "subContinent": "Nor...
# 3  {"continent": "Americas", "subContinent": "Nor...
# 4  {"continent": "Americas", "subContinent": "Nor...
#
#                         sessionId  socialEngagementType  \
# 0  6194193421514403509_1472843572  Not Socially Engaged
# 1  5327166854580374902_1472844906  Not Socially Engaged
# 2  8885051388942907862_1472827393  Not Socially Engaged
# 3  0185467632009737931_1472846398  Not Socially Engaged
# 4  3244885836845029978_1472824817  Not Socially Engaged
#
#                                        trafficSource     visitId  visitNumber  \
# 0  {"campaign": "(not set)", "source": "(direct)"...  1472843572            1
# 1  {"campaign": "(not set)", "source": "google", ...  1472844906            3
# 2  {"referralPath": "/", "campaign": "(not set)",...  1472827393            7
# 3  {"referralPath": "/", "campaign": "(not set)",...  1472846398            6
# 4  {"referralPath": "/", "campaign": "(not set)",...  1472824817            4
#
#    visitStartTime totals.bounces totals.hits totals.newVisits  \
# 0      1472843572            NaN          11                1
# 1      1472844906            NaN          11              NaN
# 2      1472827393            NaN          13              NaN
# 3      1472846398            NaN          13              NaN
# 4      1472824817            NaN          17              NaN
#
#   totals.pageviews  totals.transactionRevenue totals.visits
# 0               11                 37860000.0             1
# 1               10                306670000.0             1
# 2               11                 68030000.0             1
# 3               12                 26250000.0             1
# 4               14                574150000.0             1
