# %% [markdown]
# ## Google analytics customer revenue predictions
# ### By Ahmed Eweed
#
# ### You can find me on github at [github.com/AhmedEweed](https://github.com/AhmedEweed)

# %% [markdown]
#     I re approached the dataset as I explored it in many ways
#     and this version is the updated version of my exploration

# %%
import os
import json
import numpy as np
import pandas as pd
from pandas.io.json import json_normalize
# load dataset with the option to specify which column to flatten from json and the datatypes of each column
def load_df(csv_path=None, Json=[], dtype = {}):
    JSON_COLUMNS = Json
    df = pd.read_csv(csv_path, 
                     converters={column: json.loads for column in JSON_COLUMNS}, 
                     dtype=dtype,
                     )
    
    for column in JSON_COLUMNS:
        column_as_df = json_normalize(df[column])
        column_as_df.columns = [f"{column}.{subcolumn}" for subcolumn in column_as_df.columns]
        df = df.drop(column, axis=1).merge(column_as_df, right_index=True, left_index=True)
    print(f"Loaded {os.path.basename(csv_path)}. Shape: {df.shape}")
    return df

# %%
#load dataset
df = load_df('../train.csv', ['totals'])
df.head()
# Out:
# Loaded train.csv. Shape: (903653, 17)
#   channelGrouping      date  \
# 0  Organic Search  20160902
# 1  Organic Search  20160902
# 2  Organic Search  20160902
# 3  Organic Search  20160902
# 4  Organic Search  20160902
#
#                                               device  fullVisitorId  \
# 0  {"browser": "Chrome", "browserVersion": "not a...   1.131660e+18
# 1  {"browser": "Firefox", "browserVersion": "not ...   3.773060e+17
# 2  {"browser": "Chrome", "browserVersion": "not a...   3.895550e+18
# 3  {"browser": "UC Browser", "browserVersion": "n...   4.763450e+18
# 4  {"browser": "Chrome", "browserVersion": "not a...   2.729440e+16
#
#                                           geoNetwork  \
# 0  {"continent": "Asia", "subContinent": "Western...
# 1  {"continent": "Oceania", "subContinent": "Aust...
# 2  {"continent": "Europe", "subContinent": "South...
# 3  {"continent": "Asia", "subContinent": "Southea...
# 4  {"continent": "Europe", "subContinent": "North...
#
#                         sessionId  socialEngagementType  \
# 0  1131660440785968503_1472830385  Not Socially Engaged
# 1   377306020877927890_1472880147  Not Socially Engaged
# 2  3895546263509774583_1472865386  Not Socially Engaged
# 3  4763447161404445595_1472881213  Not Socially Engaged
# 4    27294437909732085_1472822600  Not Socially Engaged
#
#                                        trafficSource     visitId  visitNumber  \
# 0  {"campaign": "(not set)", "source": "google", ...  1472830385            1
# 1  {"campaign": "(not set)", "source": "google", ...  1472880147            1
# 2  {"campaign": "(not set)", "source": "google", ...  1472865386            1
# 3  {"campaign": "(not set)", "source": "google", ...  1472881213            1
# 4  {"campaign": "(not set)", "source": "google", ...  1472822600            2
#
#    visitStartTime totals.bounces totals.hits totals.newVisits  \
# 0      1472830385              1           1                1
# 1      1472880147              1           1                1
# 2      1472865386              1           1                1
# 3      1472881213              1           1                1
# 4      1472822600              1           1              NaN
#
#   totals.pageviews totals.transactionRevenue totals.visits
# 0                1                       NaN             1
# 1                1                       NaN             1
# 2                1                       NaN             1
# 3                1                       NaN             1
# 4                1                       NaN             1

# %%
# look up the datatypes present in the dataset
df.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 903653 entries, 0 to 903652
# Data columns (total 17 columns):
# channelGrouping              903653 non-null object
# date                         903653 non-null int64
# device                       903653 non-null object
# fullVisitorId                903653 non-null float64
# geoNetwork                   903653 non-null object
# sessionId                    903653 non-null object
# socialEngagementType         903653 non-null object
# trafficSource                903653 non-null object
# visitId                      903653 non-null int64
# visitNumber                  903653 non-null int64
# visitStartTime               903653 non-null int64
# totals.bounces               450630 non-null object
# totals.hits                  903653 non-null object
# totals.newVisits             703060 non-null object
# totals.pageviews             903553 non-null object
# totals.transactionRevenue    11515 non-null object
# totals.visits                903653 non-null object
# dtypes: float64(1), int64(4), object(12)
# memory usage: 117.2+ MB

# %%
# convert revenue to float
df['totals.transactionRevenue'] = df['totals.transactionRevenue'].astype(float)

# %%
# extract only numeric values of revenue
df_part = df[df['totals.transactionRevenue'] > 0.0]

# %%
# reset the index of the the new extracted dataset
df_part = df_part.reset_index(drop = True)

# %%
# look up the date column format
df_part['date'].head()
# Out:
# 0    20160902
# 1    20160902
# 2    20160902
# 3    20160902
# 4    20160902
# Name: date, dtype: int64

# %%
# convert date to the right format
df_part['date'] = pd.to_datetime(df_part['date'], format = '%Y%m%d')

# %%
# save extracted dataset
df_part.to_csv('revenue_data.csv', index = False)

# %%
# load our brand new dataset
df_part = load_df('revenue_data.csv', ['device', 'geoNetwork', 'trafficSource'], {'fullVisitorId': 'str'})
# Out:
# Loaded revenue_data.csv. Shape: (11515, 54)

# %%
# look at the dataset
df_part.head()
# Out:
#   channelGrouping        date fullVisitorId                       sessionId  \
# 0          Direct  2016-09-02   6.19419e+18  6194193421514403509_1472843572
# 1  Organic Search  2016-09-02   5.32717e+18  5327166854580374902_1472844906
# 2        Referral  2016-09-02   8.88505e+18  8885051388942907862_1472827393
# 3        Referral  2016-09-02   1.85468e+17  0185467632009737931_1472846398
# 4        Referral  2016-09-02   3.24489e+18  3244885836845029978_1472824817
#
#    socialEngagementType     visitId  visitNumber  visitStartTime  \
# 0  Not Socially Engaged  1472843572            1      1472843572
# 1  Not Socially Engaged  1472844906            3      1472844906
# 2  Not Socially Engaged  1472827393            7      1472827393
# 3  Not Socially Engaged  1472846398            6      1472846398
# 4  Not Socially Engaged  1472824817            4      1472824817
#
#    totals.bounces  totals.hits          ...           \
# 0             NaN           11          ...
# 1             NaN           11          ...
# 2             NaN           13          ...
# 3             NaN           13          ...
# 4             NaN           17          ...
#
#    trafficSource.adwordsClickInfo.gclId  \
# 0                                   NaN
# 1                                   NaN
# 2                                   NaN
# 3                                   NaN
# 4                                   NaN
#
#    trafficSource.adwordsClickInfo.isVideoAd  \
# 0                                       NaN
# 1                                       NaN
# 2                                       NaN
# 3                                       NaN
# 4                                       NaN
#
#    trafficSource.adwordsClickInfo.page  trafficSource.adwordsClickInfo.slot  \
# 0                                  NaN                                  NaN
# 1                                  NaN                                  NaN
# 2                                  NaN                                  NaN
# 3                                  NaN                                  NaN
# 4                                  NaN                                  NaN
#
#   trafficSource.campaign trafficSource.isTrueDirect trafficSource.keyword  \
# 0              (not set)                       True                   NaN
# 1              (not set)                       True        (not provided)
# 2              (not set)                       True                   NaN
# 3              (not set)                       True                   NaN
# 4              (not set)                       True                   NaN
#
#   trafficSource.medium trafficSource.referralPath  trafficSource.source
# 0               (none)                        NaN              (direct)
# 1              organic                        NaN                google
# 2             referral                          /   mall.googleplex.com
# 3             referral                          /   mall.googleplex.com
# 4             referral                          /   mall.googleplex.com
#
# [5 rows x 54 columns]

# %%
# look at datatypes
df_part.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 11515 entries, 0 to 11514
# Data columns (total 54 columns):
# channelGrouping                                      11515 non-null object
# date                                                 11515 non-null object
# fullVisitorId                                        11515 non-null object
# sessionId                                            11515 non-null object
# socialEngagementType                                 11515 non-null object
# visitId                                              11515 non-null int64
# visitNumber                                          11515 non-null int64
# visitStartTime                                       11515 non-null int64
# totals.bounces                                       0 non-null float64
# totals.hits                                          11515 non-null int64
# totals.newVisits                                     4465 non-null float64
# totals.pageviews                                     11515 non-null int64
# totals.transactionRevenue                            11515 non-null float64
# totals.visits                                        11515 non-null int64
# device.browser                                       11515 non-null object
# device.browserSize                                   11515 non-null object
# device.browserVersion                                11515 non-null object
# device.deviceCategory                                11515 non-null object
# device.flashVersion                                  11515 non-null object
# device.isMobile                                      11515 non-null bool
# device.language                                      11515 non-null object
# device.mobileDeviceBranding                          11515 non-null object
# device.mobileDeviceInfo                              11515 non-null object
# device.mobileDeviceMarketingName                     11515 non-null object
# device.mobileDeviceModel                             11515 non-null object
# device.mobileInputSelector                           11515 non-null object
# device.operatingSystem                               11515 non-null object
# device.operatingSystemVersion                        11515 non-null object
# device.screenColors                                  11515 non-null object
# device.screenResolution                              11515 non-null object
# geoNetwork.city                                      11515 non-null object
# geoNetwork.cityId                                    11515 non-null object
# geoNetwork.continent                                 11515 non-null object
# geoNetwork.country                                   11515 non-null object
# geoNetwork.latitude                                  11515 non-null object
# geoNetwork.longitude                                 11515 non-null object
# geoNetwork.metro                                     11515 non-null object
# geoNetwork.networkDomain                             11515 non-null object
# geoNetwork.networkLocation                           11515 non-null object
# geoNetwork.region                                    11515 non-null object
# geoNetwork.subContinent                              11515 non-null object
# trafficSource.adContent                              143 non-null object
# trafficSource.adwordsClickInfo.adNetworkType         454 non-null object
# trafficSource.adwordsClickInfo.criteriaParameters    11515 non-null object
# trafficSource.adwordsClickInfo.gclId                 456 non-null object
# trafficSource.adwordsClickInfo.isVideoAd             454 non-null object
# trafficSource.adwordsClickInfo.page                  454 non-null object
# trafficSource.adwordsClickInfo.slot                  454 non-null object
# trafficSource.campaign                               11515 non-null object
# trafficSource.isTrueDirect                           7004 non-null object
# trafficSource.keyword                                3871 non-null object
# trafficSource.medium                                 11515 non-null object
# trafficSource.referralPath                           5415 non-null object
# trafficSource.source                                 11515 non-null object
# dtypes: bool(1), float64(3), int64(6), object(44)
# memory usage: 4.7+ MB

# %%
# look at each cloumn's values to drop any empty or irrelevant ones
for item in df_part.columns:
    print(df_part[item].value_counts())
# Out:
# Referral          5311
# Organic Search    3438
# Direct            2042
# Paid Search        468
# Display            142
# Social             104
# Affiliates           9
# (Other)              1
# Name: channelGrouping, dtype: int64
# 2016-12-16    87
# 2016-12-12    83
# 2017-05-01    78
# 2016-12-13    77
# 2016-12-05    76
# 2016-11-28    73
# 2016-12-09    72
# 2016-12-15    72
# 2016-08-12    71
# 2017-05-03    70
# 2016-12-06    70
# 2016-12-19    69
# 2017-05-02    67
# 2016-12-20    67
# 2017-02-17    67
# 2016-12-08    66
# 2016-08-15    65
# 2016-12-14    65
# 2017-07-13    62
# 2016-08-25    62
# 2017-07-31    61
# 2017-06-12    61
# 2016-08-16    59
# 2017-04-28    59
# 2016-11-30    57
# 2016-08-23    57
# 2016-08-22    57
# 2017-07-19    56
# 2017-05-12    54
# 2017-02-14    51
#               ..
# 2017-02-25    12
# 2016-10-08    12
# 2017-05-06    12
# 2017-05-07    11
# 2017-01-21    11
# 2017-03-12    11
# 2017-01-14    11
# 2017-01-08    11
# 2017-01-01    11
# 2016-10-29    11
# 2017-05-14    10
# 2016-12-31    10
# 2017-01-22    10
# 2017-06-24    10
# 2017-04-09    10
# 2017-02-11    10
# 2016-08-06    10
# 2017-05-28     9
# 2017-02-26     9
# 2016-09-04     9
# 2016-10-15     9
# 2016-09-17     8
# 2017-01-07     8
# 2017-07-02     8
# 2017-04-15     7
# 2017-07-04     7
# 2017-01-15     6
# 2016-10-01     6
# 2017-01-28     4
# 3.739200e+08      1
# 2.819000e+07      1
# 9.047000e+07      1
# 3.073000e+07      1
# 1.535700e+08      1
# 4.678000e+07      1
# 1.405900e+08      1
# 2.236000e+07      1
# 1.313100e+08      1
# 2.039000e+08      1
# 2.306000e+07      1
# 1.026900e+08      1
# 1.710000e+07      1
# 4.049000e+07      1
# 8.995000e+08      1
# 2.987600e+08      1
# 4.917000e+08      1
# 6.356000e+07      1
# 4.154000e+07      1
# 1.639000e+07      1
# Name: totals.transactionRevenue, Length: 5332, dtype: int64
# 1    11515
# Name: totals.visits, dtype: int64
# Chrome               10353
# Safari                 780
# Firefox                191
# Internet Explorer      109
# Edge                    58
# Safari (in-app)         12
# Android Webview          6
# Opera                    5
# Amazon Silk              1
# Name: device.browser, dtype: int64
# not available in demo dataset    11515
# Name: device.browserSize, dtype: int64
# not available in demo dataset    11515
# Name: device.browserVersion, dtype: int64
# desktop    10495
# mobile       852
# tablet       168
# Name: device.deviceCategory, dtype: int64
# not available in demo dataset    11515
# Name: device.flashVersion, dtype: int64
# False    10495
# True      1020
# Name: device.isMobile, dtype: int64
# not available in demo dataset    11515
# Name: device.language, dtype: int64
# not available in demo dataset    11515
# Name: device.mobileDeviceBranding, dtype: int64
# not available in demo dataset    11515
# Name: device.mobileDeviceInfo, dtype: int64
# not available in demo dataset    11515
# Name: device.mobileDeviceMarketingName, dtype: int64
# not available in demo dataset    11515
# Name: device.mobileDeviceModel, dtype: int64
# not available in demo dataset    11515
# Name: device.mobileInputSelector, dtype: int64
# Macintosh        6426
# Windows          2309
# Chrome OS         994
# Linux             782
# iOS               536
# Android           467
# Windows Phone       1
# Name: device.operatingSystem, dtype: int64
# not available in demo dataset    11515
# Name: device.operatingSystemVersion, dtype: int64
# not available in demo dataset    11515
# Name: device.screenColors, dtype: int64
# not available in demo dataset    11515
# Name: device.screenResolution, dtype: int64
# not available in demo dataset    4579
# New York                         1506
# Mountain View                    1209
# San Francisco                     729
# Sunnyvale                         455
# Chicago                           422
# Los Angeles                       289
# Seattle                           228
# Austin                            210
# San Jose                          202
# Ann Arbor                         193
# Cambridge                         119
# San Bruno                         103
# Kirkland                          101
# Washington                         98
# Atlanta                            98
# Santa Clara                        80
# Toronto                            64
# Salem                              57
# Houston                            56
# Irvine                             53
# (not set)                          49
# Palo Alto                          48
# Pittsburgh                         39
# San Diego                          38
# Maracaibo                          36
# Boulder                            24
# Dallas                             24
# Fremont                            19
# Cupertino                          18
#                                  ...
# Jacksonville                        1
# Tigard                              1
# Saratoga                            1
# Kitchener                           1
# Fresno                              1
# Athens                              1
# Bogota                              1
# Vienna                              1
# Syracuse                            1
# Detroit                             1
# San Marcos                          1
# Dubai                               1
# Bengaluru                           1
# Hamden                              1
# Warsaw                              1
# Berlin                              1
# Dundalk                             1
# Bucharest                           1
# Buenos Aires                        1
# Cincinnati                          1
# Evanston                            1
# Milwaukee                           1
# La Victoria                         1
# Yokohama                            1
# Quezon City                         1
# Prague                              1
# El Paso                             1
# Barrie                              1
# Fort Collins                        1
# North Attleborough                  1
# Name: geoNetwork.city, Length: 134, dtype: int64
# not available in demo dataset    11515
# Name: geoNetwork.cityId, dtype: int64
# Americas     11283
# Asia           125
# Europe          79
# Oceania         14
# Africa           8
# (not set)        6
# Name: geoNetwork.continent, dtype: int64
# United States     10953
# Canada              190
# Venezuela            63
# Mexico               20
# Taiwan               19
# Japan                17
# United Kingdom       16
# Australia            13
# Puerto Rico          11
# Indonesia            11
# Singapore            10
# Brazil               10
# India                10
# Hong Kong             9
# Switzerland           9
# South Korea           8
# Germany               8
# Colombia              8
# (not set)             6
# China                 6
# Ireland               6
# Israel                6
# Belgium               5
# France                5
# Argentina             5
# Thailand              5
# Chile                 5
# Russia                4
# Ukraine               4
# Ecuador               4
#                   ...
# Spain                 2
# St. Lucia             2
# Guatemala             2
# Sweden                2
# Nigeria               2
# Kuwait                2
# Georgia               2
# Peru                  2
# Italy                 2
# Turkey                2
# South Africa          2
# Panama                2
# Kazakhstan            2
# Lebanon               1
# Pakistan              1
# New Zealand           1
# Hungary               1
# Nicaragua             1
# Uruguay               1
# Curaçao               1
# Anguilla              1
# Cyprus                1
# Guadeloupe            1
# Egypt                 1
# El Salvador           1
# Romania               1
# Czechia               1
# Portugal              1
# Armenia               1
# Denmark               1
# Name: geoNetwork.country, Length: 69, dtype: int64
# not available in demo dataset    11515
# Name: geoNetwork.latitude, dtype: int64
# not available in demo dataset    11515
# Name: geoNetwork.longitude, dtype: int64
# not available in demo dataset         4579
# San Francisco-Oakland-San Jose CA     2919
# New York NY                           1518
# Chicago IL                             423
# Los Angeles CA                         343
# Seattle-Tacoma WA                      336
# (not set)                              269
# Austin TX                              210
# Detroit MI                             194
# Boston MA-Manchester NH                136
# Atlanta GA                              99
# Washington DC (Hagerstown MD)           98
# Roanoke-Lynchburg VA                    57
# Houston TX                              56
# Denver CO                               40
# Pittsburgh PA                           39
# San Diego CA                            39
# Dallas-Ft. Worth TX                     26
# Phoenix AZ                              14
# Portland OR                             13
# Charlotte NC                            13
# London                                  11
# Philadelphia PA                         11
# Nashville TN                            11
# San Antonio TX                          10
# Omaha NE                                 8
# Minneapolis-St. Paul MN                  6
# Kansas City MO                           5
# Columbus OH                              4
# Miami-Ft. Lauderdale FL                  4
# Orlando-Daytona Beach-Melbourne FL       4
# Fresno-Visalia CA                        3
# Charleston SC                            3
# Salt Lake City UT                        2
# Providence-New Bedford,MA                1
# Las Vegas NV                             1
# Milwaukee WI                             1
# Cincinnati OH                            1
# Syracuse NY                              1
# Indianapolis IN                          1
# El Paso TX                               1
# Jacksonville FL                          1
# Baltimore MD                             1
# Raleigh-Durham (Fayetteville) NC         1
# Hartford & New Haven CT                  1
# Sacramento-Stockton-Modesto CA           1
# Name: geoNetwork.metro, dtype: int64
# (not set)              6645
# comcast.net             934
# verizon.net             469
# unknown.unknown         400
# rr.com                  364
# comcastbusiness.net     294
# cox.net                 156
# sbcglobal.net           150
# optonline.net           133
# qwest.net                88
# rcn.com                  68
# bhn.net                  65
# cantv.net                52
# ztomy.com                50
# att.net                  45
# com                      40
# wayport.net              34
# suddenlink.net           33
# mycingular.net           30
# managed-otrs.com         29
# travelnet.mx             27
# windstream.net           24
# bell.ca                  22
# telepacific.net          22
# rogers.com               22
# frontiernet.net          22
# mchsi.com                21
# twtelecom.net            21
# cogentco.com             18
# embarqhsd.net            16
#                        ...
# bardstowncable.net        1
# acgtexas.com              1
# wisc.edu                  1
# mpinet.com                1
# upenn.edu                 1
# digitalwest.net           1
# avast.com                 1
# seacomnet.com             1
# as5580.net                1
# fiu.edu                   1
# cwctc.org                 1
# zaq.ne.jp                 1
# emory.edu                 1
# bechtel.com               1
# wtrt.net                  1
# unl.edu                   1
# akqa.com                  1
# allis-roller.com          1
# directonpc.net            1
# alshamil.net.ae           1
# jetblue.com               1
# allcareipa.com            1
# virtua.com.br             1
# sfr.net                   1
# sajy.com                  1
# washington.edu            1
# gouv.com                  1
# moric.org                 1
# itv-3.com                 1
# dnspure.com               1
# Name: geoNetwork.networkDomain, Length: 732, dtype: int64
# not available in demo dataset    11515
# Name: geoNetwork.networkLocation, dtype: int64
# not available in demo dataset    4579
# California                       3305
# New York                         1507
# Illinois                          423
# Washington                        336
# Texas                             303
# Michigan                          194
# Massachusetts                     137
# Georgia                            99
# District of Columbia               98
# Ontario                            68
# Virginia                           57
# Pennsylvania                       50
# (not set)                          46
# Colorado                           40
# Zulia                              36
# North Carolina                     14
# Arizona                            14
# Oregon                             13
# New Jersey                         12
# Tennessee                          11
# England                            11
# Quebec                             11
# Florida                             9
# Mexico City                         7
# Jakarta                             7
# State of Sao Paulo                  7
# Taipei City                         6
# Minnesota                           6
# New South Wales                     6
#                                  ...
# Istanbul                            2
# State of Rio de Janeiro             2
# Utah                                2
# Alberta                             2
# Santiago Metropolitan Region        2
# Dublin City                         1
# Bogota                              1
# Lima Region                         1
# Attica                              1
# Tbilisi                             1
# Connecticut                         1
# Vienna                              1
# Hamburg                             1
# Bucharest                           1
# North Holland                       1
# Maharashtra                         1
# Kanagawa Prefecture                 1
# Stockholm County                    1
# Metro Manila                        1
# Berlin                              1
# Indiana                             1
# Wisconsin                           1
# Masovian Voivodeship                1
# Pichincha                           1
# Dubai                               1
# Karnataka                           1
# Prague                              1
# Gujarat                             1
# Buenos Aires                        1
# Maryland                            1
# Name: geoNetwork.region, Length: 79, dtype: int64
# Northern America    11143
# South America          98
# Eastern Asia           59
# Southeast Asia         32
# Western Europe         30
# Northern Europe        27
# Central America        26
# Western Asia           21
# Caribbean              16
# Eastern Europe         14
# Australasia            14
# Southern Asia          11
# Southern Europe         8
# (not set)               6
# Eastern Africa          3
# Southern Africa         2
# Western Africa          2
# Central Asia            2
# Northern Africa         1
# Name: geoNetwork.subContinent, dtype: int64
# Google Merchandise Collection      117
# Full auto ad IMAGE ONLY              5
# Google Online Store                  4
# Display Ad created 3/11/14           3
# {KeyWord:Google Branded Gear}        3
# Swag with Google Logos               3
# 20% discount                         2
# {KeyWord:Want Google Stickers?}      2
# {KeyWord:Google Drinkware}           1
# {KeyWord:Google Men's T-Shirts}      1
# Display Ad created 11/17/14          1
# Display Ad created 3/11/15           1
# Name: trafficSource.adContent, dtype: int64
# Google Search    454
# Name: trafficSource.adwordsClickInfo.adNetworkType, dtype: int64
# not available in demo dataset    11515
# Name: trafficSource.adwordsClickInfo.criteriaParameters, dtype: int64
# CjwKEAiAj7TCBRCp2Z22ue-zrj4SJACG7SBExAsUjtkXuYAawLBg74jzCi7nH6wWoAshJH2ZmSvBABoCiALw_wcB        3
# Cj0KEQjw-73GBRCC7KODl9zToJMBEiQAj
# 1    454
# Name: trafficSource.adwordsClickInfo.page, dtype: int64
# Top    449
# RHS      5
# Name: trafficSource.adwordsClickInfo.slot, dtype: int64
# (not set)                                          11050
# AW - Dynamic Search Ads Whole Site                   323
# AW - Accessories                                     130
# Data Share Promo                                       9
# AW - Apparel                                           1
# Retail (DO NOT EDIT owners nophakun and tianyu)        1
# test-liyuhz                                            1
# Name: trafficSource.campaign, dtype: int64
# True    7004
# Name: trafficSource.isTrueDirect, dtype: int64
# (not provided)                             3387
# 6qEhsCssdK0z36ri                            261
# google merchandise store                     59
# 1hZbAqLCbjwfgOH7                             56
# Google Merchandise                           45
# (Remarketing/Content targeting)               9
# +Google +Merchandise                          7
# 1X4Me6ZKNV0zg-jV                              6
# google store                                  3
# +Google +Swag                                 3
# +Google +Gear                                 3
# +google +store                                2
# youtube merch                                 2
# google stickers                               2
# google apparel store                          2
# GOOGLE MERCHANDISE                            2
# google store merchandise                      2
# +google +merchandise +store                   2
# category_l1==166                              2
# you tube trucker cap google merchandise       1
# google shirt                                  1
# google merchandise                            1
# +google +coffee +mug                          1
# google merch                                  1
# +google +merch                                1
# +google +stores                               1
# +google+tshirts                               1
# googlemerchandisestore                        1
# (automatic matching)                          1
# googlesupport                                 1
# google items for sale                         1
# youtube merchandise store                     1
# google men's hoodie pullover                  1
# Youtube merchandise store                     1
# YouTube Merchandise                           1
# Name: trafficSource.keyword, dtype: int64
# referral     5415
# organic      3438
# (none)       2042
# cpc           468
# cpm           142
# affiliate       9
# (not set)       1
# Name: trafficSource.medium, dtype: int64
# /                                                                                                                                                                                  5151
# /mail/u/0/                                                                                                                                                                           55
# /a/google.com/forum/                                                                                                                                                                 35
# /google-merchandise-store                                                                                                                                                            22
# /offer/2145                                                                                                                                                                          18
# /deal/-ds-sign-up-for-google-merchandise-store-emails-for-special-coup-c179                                                                                                          17
# /a/google.com/googletopia/discounts-deals-and-free-stuff/alphabet-google-discounts                                                                                                   12
# /a/google.com/google-merchandise-store/on-site-store/mountain-view-store                                                                                                             11
# /a/google.com/google-merchandise-store/on-site-store                                                                                                                                  9
# /l.php                                                                                                                                                                                8
# /yt/about/                                                                                                                                                                            8
# /od/Things-To-Do-in-Silicon-Valley/fl/How-To-Visit-the-Googleplex-the-Google-Head-Office-in-Mountain-View.htm                                                                         6
# /2015/03/11/google-merch-store-new-url/                                                                                                                                               6
# /permissions/using-the-logo.html                                                                                                                                                      5
# /Rewards/Products/Details.aspx                                                                                                                                                        4
# /forum/                                                                                                                                                                               3
# /neo/launch                                                                                                                                                                           3
# /mail/u/1/                                                                                                                                                                            3
# /a/google.com/google-merchandise-store/home/on-site-store                                                                                                                             2
# /mail/ca/u/0/                                                                                                                                                                         2
# /a/google.com/nestlabs/nestling/nestling                                                                                                                                              2
# /external-link.jspa                                                                                                                                                                   2
# /QpXvjwMv6t                                                                                                                                                                           2
# /corp/google.com/google-merchandise-store/faqs                                                                                                                                        2
# /a/google.com/another-attempt-google-merchandise-store/mountain-view-on-site-merchandise-store                                                                                        1
# /HBtw4R2RL5                                                                                                                                                                           1
# /Lw3hzUjkK9                                                                                                                                                                           1
# /_/scs/mail-static/_/js/k=gmail.main.en.yASPeSEQ5YQ.O/m=m_i,t/am=OotXDrD_7_3BuIZhQFf6at3573--_VR26Oce_58IiCKvAv3___8A_w_ko20U/rt=h/d=1/rs=AHGWq9DZAa74rKvcihAYhdWoJ70MBwYmVA          1
# /calendar/r/week/2017/7/8                                                                                                                                                             1
# /neo/rd                                                                                                                                                                               1
# /neo/b/message                                                                                                                                                                        1
# /xud9jul6em                                                                                                                                                                           1
# /Google/shop.axd/ValidateLogin                                                                                                                                                        1
# /KtfjgWJtWs                                                                                                                                                                           1
# /webmail/en-us/tablet                                                                                                                                                                 1
# /r/chromeos/comments/39boco/looking_for_chrome_sticker/                                                                                                                               1
# /IUI6ugD07C                                                                                                                                                                           1
# /deal/-ds-1655-youtube-player-tshirt-unisex-vs-1780-list                                                                                                                              1
# /2610273/projects/12161610/todos/250267685                                                                                                                                            1
# /yt/about/copyright/                                                                                                                                                                  1
# /document/d/1uELQ97D_yoYkVD_C7Jqc2i1R2gQfn9H0KjfVbu3m-kU/edit                                                                                                                         1
# /_/scs/mail-static/_/js/k=gmail.main.en.sXDiEpUnPe0.O/m=m_i,t,it/am=nhGvDGD-3_uDcQ3DgK701brz33u-Xyo_e7nH_ycDROlVoP_N_h_A_4H-tI0C/rt=h/d=1/rs=AHGWq9Bm-1qj1hhkb8cG9EpeilyYgWjoxA       1
# /Where-can-I-buy-a-stuffed-Go-language-gopher-mascot-online                                                                                                                           1
# /a/google.com/google-merchandise-store/newsite/on-site-store/mountain-view-store                                                                                                      1
# /a/google.com/aa-noogler/getting-started/training-schedule                                                                                                                            1
# /photos/google-dog-toy-21237.html                                                                                                                                                     1
# /watch                                                                                                                                                                                1
# /search/GGmain.jhtml                                                                                                                                                                  1
# /yt/about/en-GB/                                                                                                                                                                      1
# /community/partners/local-sites/japanese/gsuite/marketing/google-store                                                                                                                1
# /site/northcountycomputer/                                                                                                                                                            1
# Name: trafficSource.referralPath, dtype: int64
# mall.googleplex.com          5103
# google                       3879
# (direct)                     2042
# dfa                           123
# mail.google.com                62
# sites.google.com               42
# dealspotr.com                  40
# groups.google.com              38
# yahoo                          22
# bing                           21
# facebook.com                   20
# gdeals.googleplex.com          18
# l.facebook.com                 13
# youtube.com                    11
# Partners                        9
# t.co                            7
# m.facebook.com                  6
# phandroid.com                   6
# siliconvalley.about.com         6
# google.com                      5
# plus.google.com                 5
# mg.mail.yahoo.com               4
# googleux.perksplus.com          4
# ask                             4
# connect.googleforwork.com       3
# trainup.withgoogle.com          2
# pinterest.com                   2
# keep.google.com                 2
# us-mg5.mail.yahoo.com           1
# basecamp.com                    1
# gatewaycdi.com                  1
# outlook.live.com                1
# search.myway.com                1
# l.messenger.com                 1
# moma.corp.google.com            1
# quora.com                       1
# chat.google.com                 1
# duckduckgo.com                  1
# docs.google.com                 1
# seroundtable.com                1
# search.xfinity.com              1
# reddit.com                      1
# mail.aol.com                    1
# calendar.google.com             1
# Name: trafficSource.source, dtype: int64

# %%
# drop empty and not needed columns
df_part = df_part.drop(['geoNetwork.networkLocation',
              'geoNetwork.latitude',
              'geoNetwork.longitude',
              'trafficSource.adwordsClickInfo.criteriaParameters',
              'socialEngagementType',
              'totals.bounces',
              'device.browserSize',
              'device.browserVersion',
              'device.flashVersion',
              'device.language',
              'device.mobileDeviceBranding',
              'device.mobileDeviceInfo',
              'device.mobileDeviceModel',
              'device.mobileInputSelector',
              'device.mobileDeviceMarketingName',
              'device.operatingSystemVersion',
              'device.screenColors',
              'device.screenResolution',
              'geoNetwork.cityId'], axis = 1)

# %%
# rename columns 
df_part.rename(columns ={'channelGrouping':'channel',
                         'totals.hits':'hits',
                         'totals.newVisits':'newvisits',
                         'totals.pageviews':'pageviews',
                         'totals.transactionRevenue':'transrevenue', 
                         'totals.visits':'visits',
                         'device.browser':'browser',
                         'device.deviceCategory':'devicecategory', 
                         'device.isMobile':'ismobile',
                         'device.operatingSystem':'os',
                         'geoNetwork.city':'city', 
                         'geoNetwork.continent':'continent',
                         'geoNetwork.country':'country', 
                         'geoNetwork.metro':'metro',
                         'geoNetwork.networkDomain':'networkdomain',
                         'geoNetwork.region':'region',
                         'geoNetwork.subContinent':'subcontinent',
                         'trafficSource.adContent':'adContent',
                         'trafficSource.adwordsClickInfo.adNetworkType':'adNetworkType',
                         'trafficSource.adwordsClickInfo.gclId':'gclId',
                         'trafficSource.adwordsClickInfo.isVideoAd':'isVideoAd',
                         'trafficSource.adwordsClickInfo.page':'page',
                         'trafficSource.adwordsClickInfo.slot':'slot', 'trafficSource.campaign':'campaign',
                         'trafficSource.isTrueDirect':'istruedirect', 'trafficSource.keyword':'keyword',
                         'trafficSource.medium':'medium', 'trafficSource.referralPath':'referalpath',
                         'trafficSource.source':'source'}, inplace = True)

# %%
# look at the dataset
df_part.tail()
# Out:
#         channel        date fullVisitorId                       sessionId  \
# 11510  Referral  2017-01-04    6.8496e+18  6849604863010168468_1483566314
# 11511  Referral  2017-01-04   2.11987e+17  0211986650009953276_1483568879
# 11512  Referral  2017-01-04   9.98156e+18  9981562221973608723_1483576938
# 11513    Direct  2017-01-04   9.63126e+17   963126344221316701_1483552674
# 11514    Direct  2017-01-04   9.77144e+18  9771437221362506189_1483538997
#
#           visitId  visitNumber  visitStartTime  hits  newvisits  pageviews  \
# 11510  1483566314           10      1483566314    61        NaN         48
# 11511  1483568879            2      1483568879    66        NaN         30
# 11512  1483576938            1      1483576938   122        1.0         90
# 11513  1483552674            3      1483552674   130        NaN         90
# 11514  1483538997           12      1483538997   237        NaN        169
#
#               ...           gclId  isVideoAd page slot   campaign  \
# 11510         ...             NaN        NaN  NaN  NaN  (not set)
# 11511         ...             NaN        NaN  NaN  NaN  (not set)
# 11512         ...             NaN        NaN  NaN  NaN  (not set)
# 11513         ...             NaN        NaN  NaN  NaN  (not set)
# 11514         ...             NaN        NaN  NaN  NaN  (not set)
#
#       istruedirect keyword    medium referalpath               source
# 11510         True     NaN  referral           /  mall.googleplex.com
# 11511         True     NaN  referral           /  mall.googleplex.com
# 11512          NaN     NaN  referral           /  mall.googleplex.com
# 11513         True     NaN    (none)         NaN             (direct)
# 11514         True     NaN    (none)         NaN             (direct)
#
# [5 rows x 35 columns]
